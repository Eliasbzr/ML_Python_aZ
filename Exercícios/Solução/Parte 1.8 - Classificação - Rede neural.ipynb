# %% [markdown]
# ---
#
# Reconecte ao Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
DRIVE_DIRECTORY = "curso_ml"
DRIVE_DIRECTORY = os.path.join("/content/drive/MyDrive", DRIVE_DIRECTORY)

# %% [markdown]
# ---

# %%
import pickle

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from sklearn.neural_network import MLPClassifier
from yellowbrick.classifier import ConfusionMatrix

# %% [markdown]
# # Rede neural artificial

# %% [markdown]
# Comece recuperando os dados preditores, de treino e de teste, a partir do arquivo `cover_type.pkl` salvo na pasta do Drive. Lembre-se de que você deve instanciar as variáveis `X` e `y`, dos splits `train` e `test`,  na mesma ordem em que salvou.

# %%
with open(os.path.join(DRIVE_DIRECTORY, "cover_type.pkl"), "rb") as f:
    (X_train, y_train, X_test, y_test) = pickle.load(f)

# %% [markdown]
# Instancie e ajuste um classificador do tipo `MLPClassifier`. Altere os valores padrão dos parâmetros, utilizando `verbose=True`, e `hidden_layer_sizes=(100, 50)`.

# %%
mlp_classifier = MLPClassifier(verbose=True, hidden_layer_sizes=(100, 50))
mlp_classifier.fit(X_train, y_train)
# Out:
# Iteration 1, loss = 1.38739417
# Iteration 2, loss = 0.91154339
# Iteration 3, loss = 0.77801219
# Iteration 4, loss = 0.71125094
# Iteration 5, loss = 0.67197923
# Iteration 6, loss = 0.64546533
# Iteration 7, loss = 0.62790118
# Iteration 8, loss = 0.61445525
# Iteration 9, loss = 0.60414029
# Iteration 10, loss = 0.59245112
# Iteration 11, loss = 0.58045270
# Iteration 12, loss = 0.57285945
# Iteration 13, loss = 0.56557913
# Iteration 14, loss = 0.55759237
# Iteration 15, loss = 0.55285191
# Iteration 16, loss = 0.54650664
# Iteration 17, loss = 0.54179499
# Iteration 18, loss = 0.53605868
# Iteration 19, loss = 0.53044083
# Iteration 20, loss = 0.52383733
# Iteration 21, loss = 0.51890280
# Iteration 22, loss = 0.51548068
# Iteration 23, loss = 0.51066903
# Iteration 24, loss = 0.51146431
# Iteration 25, loss = 0.50249554
# Iteration 26, loss = 0.49819020
# Iteration 27, loss = 0.49395296
# Iteration 28, loss = 0.49009316
# Iteration 29, loss = 0.48793456
# Iteration 30, loss = 0.48210904
# Iteration 31, loss = 0.47855984
# Iteration 32, loss = 0.47396065
# Iteration 33, loss = 0.47350912
# Iteration 34, loss = 0.46971851
# Iteration 35, loss = 0.46525089
# Iteration 36, loss = 0.46113974
# Iteration 37, loss = 0.45651355
# Iteration 38, loss = 0.45451568
# Iteration 39, loss = 0.44927699
# Iteration 40, loss = 0.44777731
# Iteration 41, loss = 0.44519841
# Iteration 42, loss = 0.43975986
# Iteration 43, loss = 0.44140946
# Iteration 44, loss = 0.43418056
# Iteration 45, loss = 0.43208626
# Iteration 46, loss = 0.42811910
# Iteration 47, loss = 0.42349137
# Iteration 48, loss = 0.42276260
# Iteration 49, loss = 0.42018536
# Iteration 50, loss = 0.41544951
# Iteration 51, loss = 0.41561537
# Iteration 52, loss = 0.41089557
# Iteration 53, loss = 0.40752291
# Iteration 54, loss = 0.40500925
# Iteration 55, loss = 0.40196364
# Iteration 56, loss = 0.40054893
# Iteration 141, loss = 0.25886542
# Iteration 142, loss = 0.25876969
# Iteration 143, loss = 0.25740910
# Iteration 144, loss = 0.25862709
# Iteration 145, loss = 0.25589714
# Iteration 146, loss = 0.25453064
# Iteration 147, loss = 0.25147336
# Iteration 148, loss = 0.25244331
# Iteration 149, loss = 0.25340805
# Iteration 150, loss = 0.24940793
# Iteration 151, loss = 0.24786688
# Iteration 152, loss = 0.24593913
# Iteration 153, loss = 0.24754590
# Iteration 154, loss = 0.24931998
# Iteration 155, loss = 0.24724529
# Iteration 156, loss = 0.24512830
# Iteration 157, loss = 0.24135260
# Iteration 158, loss = 0.24129068
# Iteration 159, loss = 0.24522302
# Iteration 160, loss = 0.24048792
# Iteration 161, loss = 0.23814326
# Iteration 162, loss = 0.23581762
# Iteration 163, loss = 0.23746266
# Iteration 164, loss = 0.23585219
# Iteration 165, loss = 0.23430159
# Iteration 166, loss = 0.23668426
# Iteration 167, loss = 0.23729038
# Iteration 168, loss = 0.23291597
# Iteration 169, loss = 0.23028069
# Iteration 170, loss = 0.23047536
# Iteration 171, loss = 0.22657435
# Iteration 172, loss = 0.23094906
# Iteration 173, loss = 0.22298765
# Iteration 174, loss = 0.22671882
# Iteration 175, loss = 0.22474197
# Iteration 176, loss = 0.22902499
# Iteration 177, loss = 0.22225124
# Iteration 178, loss = 0.22578616
# Iteration 179, loss = 0.21991954
# Iteration 180, loss = 0.21865365
# Iteration 181, loss = 0.22231981
# Iteration 182, loss = 0.22074952
# Iteration 183, loss = 0.23115468
# Iteration 184, loss = 0.22120132
# Iteration 185, loss = 0.21596263
# Iteration 186, loss = 0.21360925
# Iteration 187, loss = 0.21489602
# Iteration 188, loss = 0.22039516
# Iteration 189, loss = 0.21579078
# Iteration 190, loss = 0.21483135
# Iteration 191, loss = 0.21231297
# Iteration 192, loss = 0.21235831
# Iteration 193, loss = 0.21154227
# Iteration 194, loss = 0.20674729
# Iteration 195, loss = 0.21163429
# Iteration 196, loss = 0.20771437
# Iteration 197, loss = 0.20557490
# Iteration 198, loss = 0.20907179
# Iteration 199, loss = 0.20986834
# Iteration 200, loss = 0.20340639
# /usr/local/lib/python3.11/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# MLPClassifier(hidden_layer_sizes=(100, 50), verbose=True)

# %% [markdown]
# Faça e exiba a predição no split de teste.

# %%
y_pred = mlp_classifier.predict(X_test)

# %%
y_pred
# Out:
# array([4, 4, 1, ..., 6, 6, 2])

# %% [markdown]
# Calcule a acurácia.

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.778

# %% [markdown]
# Exiba a matriz de confusão.

# %%
cm = ConfusionMatrix(mlp_classifier)
cm.fit(X_train, y_train)
cm.score(X_test, y_test)
# Out:
# 0.778

# %% [markdown]
# Exiba o reporte de classificação.

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.47      0.43        34
#            1       0.43      0.62      0.51        16
#            2       0.50      0.48      0.49        67
#            3       0.74      0.75      0.74        87
#            4       0.81      0.84      0.83      1230
#            5       0.72      0.69      0.70       156
#            6       0.79      0.75      0.77       910
#
#     accuracy                           0.78      2500
#    macro avg       0.63      0.66      0.64      2500
# weighted avg       0.78      0.78      0.78      2500
